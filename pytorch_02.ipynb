# %% [markdown]
# <a href="https://colab.research.google.com/github/arpanghosh87/pytorch/blob/main/pytorch_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import datasets
import  sklearn
from sklearn.datasets import make_circles

n_samples = 1000

# create circles
X, y = make_circles(n_samples, noise=0.03, random_state=42)
